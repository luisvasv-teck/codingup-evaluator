# %% [markdown]
# <p><img src=" https://upload.wikimedia.org/wikipedia/commons/1/13/SoftServe_logo_2017.svg" alt="" width="363" height="63" /></p>
#
# ----
#
# ### **INFORMACIÓN TECNICA**
# * **ID**: PYLVL1A_R11-E4-P15
# * **Python Versión:** 3.x
# * **Versión:** 0.0.1
# ---
# ### **INTRODUCCIÓN**
#
# En este modulo se ejercitara la identificacion de como insertar comentarios
# simples y dobles en Python y como aprender a identificar sus diferencias.
#
# ### **QUE SE APRENDERA**
#
# - Definición de Comentarios.
# - Diferencia entre comentarios simples y multilinea.
# - Importancia dentro de la documentacion.
#
# ### **RESULTADOS ESPERADOS**
# ```python
# Identificacion de Comentarios
# Cuando utilizarlos
# importancia en la documentacion
# ```
#
# # **EJERCICIOS**

# %% [markdown]
# <p><img src="https://cdn.icon-icons.com/icons2/1130/PNG/512/numberoneinacircle_80030.png" alt="" width="73" height="73" /></p>
#
# * **ID** PYLVL1A-1
# * **DESCRIPCIÓN:**
#
#   Se requiere craer un ejercicio donde se multiplique `* x 5`

# %%
Check = False #@param {type:"boolean"}

# %% [markdown]
# <p><img src="https://cdn.icon-icons.com/icons2/1130/PNG/512/numbertwoinacircle_80299.png" alt="" width="73" height="73" /></p>
#
# * **ID** PYLVL1A-2
# * **DESCRIPCIÓN:**
#
#   Se requiere definir una funcion llamada `convertidor`, la cual se le envie un valor valor y lo convierta en mayuscula
#   para probar, use la palabra demo

# %%
# PYLVL1A-2
# >>> Escriba su codigo a partir de este punto <<<
def convertidor(valor):
  return valor.upper()

print(convertidor("demo"))
# Out:
# DEMO

# %%
convertidor("pepito")
# Out:
# 'PEPITO'

# %% [markdown]
# <p><img src="https://cdn.icon-icons.com/icons2/1130/PNG/512/numberthreeinacircle_80289.png" alt="" width="73" height="73" /></p>
#
# * **ID** PYLVL1A-3
# * **DESCRIPCIÓN:**
#
#   generar una división que de decimal

# %%
# PYLVL1A-3
# >>> Escriba su codigo a partir de este punto <<<
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-7a4ce0e4b861> in <cell line: 3>()
#       1 # PYLVL1A-3
#       2 # >>> Escriba su codigo a partir de este punto <<<
# ----> 3 1/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# <p><img src="https://cdn.icon-icons.com/icons2/1130/PNG/512/numberfourincircularbutton_80047.png" alt="" width="73" height="73" /></p>
#
# * **ID** PYLVL1A-4
# * **DESCRIPCIÓN:**
#
#   se requiere definir dos variables cada uno con valores de 5 y multiplicarlas

# %%
variable_1, variable2 = 5, 5
print(variable_1 + variable2)
# Out:
# 10

# %% [markdown]
# <p><img src="https://cdn.icon-icons.com/icons2/1130/PNG/512/numberfiveincircularbutton_80245.png" alt="" width="73" height="73" /></p>
#
# * **ID** PYLVL1A-4
# * **DESCRIPCIÓN:**
#
#   se requiere definir dos variables cada uno con valores de 5 y multiplicarlas

# %%
# PYLVL1A-4
# >>> Escriba su codigo a partir de este punto <<<
variable_1, variable2 = 5, 5
print(variable_1 + variable2)
# Out:
# 10
